# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Current Resources
#
# | Gold | Elixir | Dark |
# | :-: | :-: | :-: |
# | 30,000,000 | 30,000,000 | 300,000 |

# %% [markdown]
# | Barbarian King | Dark |
# | :-: | :-: |
# | 92 | 240,000 |
# | 93 | 248,000 |
# | 94 | 256,000 |
# | 95 | 264,000 |

# %% [markdown]
# | Royal Champion Level | Dark |
# | :-: | :-: |
# | 42 | 260,000 |
# | 43 | 268,000 |
# | 44 | 276,000 |
# | 45 | 284,000 |

# %%
sqrt(32^2 + 56^2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 sqrt(32^2 + 56^2)
#
# NameError: name 'sqrt' is not defined

# %%
# Sample data
x = [48, 50, 55, 65, 75, 85, 98]
y = [360, 430, 570, 680, 850, 1200, 2500]

# Create the plot
plt.scatter(x, y)

# Add a title and labels
plt.title("TV Price")
plt.xlabel("Size")
plt.ylabel("Price")

# Show the plot
plt.show()

z = [i**2 * 0.4375 for i in x]

# %%
# Create the plot
plt.scatter(x, z)

# Add a title  labels
plt.title("TV Diagonal vs Area")
plt.xlabel("Diagonal")
plt.ylabel("Size (Area)")

# Show the plot
plt.show()
